# %%
import pandas as pd
import numpy as np

pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 100)

df = pd.read_csv("Bangladesh_database_Final_Merged_30features.csv")

df.head()
# Out:
#        FPAR  Avg_Salinity_Index       EVI  Rain_Temp_Ratio  Rainfall  \
# 0  6.314995          560.494023  0.311631            11.23    220.43
# 1  6.314995          560.494023  0.311631            11.23    220.43
# 2  6.314995          560.494023  0.311631            11.23    220.43
# 3  6.314995          560.494023  0.311631            11.23    220.43
# 4  4.169442          883.021928  0.308177            22.73    656.33
#
#    Wind_Mean  Temp_Min  Wind_Max  Temp_Max  District   Clay       LAI  \
# 0   1.452917      8.35      4.33     30.58  Bagerhat  28.25  2.968781
# 1   1.452917      8.35      4.33     30.58  Bagerhat  28.25  2.968781
# 2   1.452917      8.35      4.33     30.58  Bagerhat  28.25  2.968781
# 3   1.452917      8.35      4.33     30.58  Bagerhat  28.25  2.968781
# 4   2.481885     16.01      5.86     41.26  Bagerhat  28.25  1.811287
#
#    Nitrogen  Soil_Moisture_mm    pH  LST_Kelvin Dominant_Soil_Texture  \
# 0      3.89         12.078043  5.73  297.294525   Loamy (Thịt/Phù sa)
# 1      3.89         12.078043  5.73  297.294525   Loamy (Thịt/Phù sa)
# 2      3.89         12.078043  5.73  297.294525   Loamy (Thịt/Phù sa)
# 3      3.89         12.078043  5.73  297.294525   Loamy (Thịt/Phù sa)
# 4      3.89         14.770987  5.73  301.581973   Loamy (Thịt/Phù sa)
#
#        AP Ratio  Temp_Mean  Avg Humidity  Heat_Stress_Days   Silt  \
# 0  0.7722007722  19.631500          55.0                 0  49.52
# 1   2.247030879  19.631500          60.0                 0  49.52
# 2   1.847881242  19.631500          72.5                 0  49.52
# 3    3.50877193  19.631500          80.0                 0  49.52
# 4   4.994778068  28.878197          70.0                54  49.52
#
#            Growth  CN_Ratio     Crop Name  Organic_Carbon Transplant  \
# 0  Jan  to  March      8.73         Wheat           33.97        Dec
# 1  Jan  to  March      8.73       Maize 2           33.97        Dec
# 2    Dec to March      8.73          Boro           33.97        Nov
# 3    Dec to March      8.73  Sweet Potato           33.97        Nov
# 4   No need to do      8.73         Mango           33.97      April
#
#      Season  NDVI_Season_Mean
# 0      Rabi          0.511809
# 1      Rabi          0.511809
# 2      Rabi          0.511809
# 3      Rabi          0.511809
# 4  Kharif 1          0.267147

# %%
feature_group_summary = (
    feature_dictionary
    .groupby("Group")["Feature"]
    .apply(list)
    .reset_index()
)

feature_group_summary["num_features"] = feature_group_summary["Feature"].apply(len)
feature_group_summary
# Out:
#                           Group  \
# 0        Agricultural indicator
# 1                       Climate
# 2      Climate / Remote sensing
# 3                Climate stress
# 4                          Crop
# 5                 Crop calendar
# 6                      Location
# 7                          Soil
# 8                Soil / Climate
# 9         Soil / Remote sensing
# 10  Vegetation / Remote sensing
#
#                                               Feature  num_features
# 0                                          [AP Ratio]             1
# 1   [Rain_Temp_Ratio, Rainfall, Wind_Mean, Temp_Mi...             8
# 2                                        [LST_Kelvin]             1
# 3                                  [Heat_Stress_Days]             1
# 4                                         [Crop Name]             1
# 5                        [Growth, Transplant, Season]             3
# 6                                          [District]             1
# 7   [Clay, Nitrogen, pH, Dominant_Soil_Texture, Si...             7
# 8                                  [Soil_Moisture_mm]             1
# 9                                [Avg_Salinity_Index]             1
# 10                 [FPAR, EVI, LAI, NDVI_Season_Mean]             4

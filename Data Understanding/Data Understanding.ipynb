# %%
import pandas as pd
import numpy as np
df = pd.read_csv("Bangladesh_database_Final_Merged_30features.csv")

df.head()
# Out:
#        FPAR  Avg_Salinity_Index       EVI  Rain_Temp_Ratio  Rainfall  \
# 0  6.314995          560.494023  0.311631            11.23    220.43
# 1  6.314995          560.494023  0.311631            11.23    220.43
# 2  6.314995          560.494023  0.311631            11.23    220.43
# 3  6.314995          560.494023  0.311631            11.23    220.43
# 4  4.169442          883.021928  0.308177            22.73    656.33
#
#    Wind_Mean  Temp_Min  Wind_Max  Temp_Max  District  ...  Avg Humidity  \
# 0   1.452917      8.35      4.33     30.58  Bagerhat  ...          55.0
# 1   1.452917      8.35      4.33     30.58  Bagerhat  ...          60.0
# 2   1.452917      8.35      4.33     30.58  Bagerhat  ...          72.5
# 3   1.452917      8.35      4.33     30.58  Bagerhat  ...          80.0
# 4   2.481885     16.01      5.86     41.26  Bagerhat  ...          70.0
#
#    Heat_Stress_Days   Silt          Growth  CN_Ratio     Crop Name  \
# ...

# %%
feature_group_summary = (
    feature_dictionary
    .groupby("Group")["Feature"]
    .apply(list)
    .reset_index()
)

feature_group_summary["num_features"] = feature_group_summary["Feature"].apply(len)
feature_group_summary
# Out:
#                           Group  \
# 0        Agricultural indicator
# 1                       Climate
# 2      Climate / Remote sensing
# 3                Climate stress
# 4                          Crop
# 5                 Crop calendar
# 6                      Location
# 7                          Soil
# 8                Soil / Climate
# 9         Soil / Remote sensing
# 10  Vegetation / Remote sensing
#
#                                               Feature  num_features
# 0                                          [AP Ratio]             1
# 1   [Rain_Temp_Ratio, Rainfall, Wind_Mean, Temp_Mi...             8
# 2                                        [LST_Kelvin]             1
# 3                                  [Heat_Stress_Days]             1
# 4                                         [Crop Name]             1
# 5                        [Growth, Transplant, Season]             3
# 6                                          [District]             1
# ...

# %% [markdown]
# Conclusion on Data Understanding (Kết luận chương Hiểu dữ liệu)
# Tóm lại, giai đoạn Khám phá và Hiểu dữ liệu (Data Understanding) đã giúp nhóm định hình rõ ràng toàn bộ cấu trúc, ý nghĩa vật lý và thực trạng chất lượng của tập dữ liệu hợp nhất 30 thuộc tính.
#
# Dù sở hữu nguồn tài nguyên đặc trưng vô cùng phong phú và giá trị (tích hợp từ thực địa, thổ nhưỡng, khí hậu đến viễn thám vệ tinh), tập dữ liệu thô vẫn tồn tại những rào cản kỹ thuật lớn. Các bằng chứng thực nghiệm đã chỉ ra hàng loạt lỗi nghiêm trọng bao gồm: mã lỗi hệ thống (#DIV/0!), nhiễu ngôn ngữ văn bản, khuyết thiếu lịch thời vụ sinh trưởng, mâu thuẫn logic và bất đồng bộ đơn vị đo lường vật lý.
#
# Việc nhận diện chính xác và phân loại cụ thể từng nhóm lỗi này là bước đi cốt lõi. Nó vừa giúp nhóm đánh giá đúng mức độ rủi ro của dữ liệu thô, vừa là căn cứ kỹ thuật bắt buộc để thiết lập một quy trình Tiền xử lý và Làm sạch dữ liệu (Data Preprocessing and Cleaning) ở chương kế tiếp. Đây là tiền đề quyết định để chuẩn hóa nguồn đầu vào đạt chuẩn chất lượng cao, bảo vệ các mô hình máy học phía sau khỏi hiện tượng sai lệch trọng số và quá khớp (Overfitting).
